# %% [markdown]
# # Run
# source file_name

# %% [markdown]
# # Load case
# https://opensees.ist.berkeley.edu/wiki/index.php?title=Getting_Started_with_OpenSees_--_Problem_Definition
# ![Load case](.\\LoadCase.jpg "load case")

# %% [markdown]
# # Model
# https://opensees.ist.berkeley.edu/wiki/index.php?title=Model_command
# <p>model basic -ndm 2 -ndf 3   # dimension & dof of nodes<br>
# 1 -> 1, 2 -> 3, 3 -> 6</p>

# %% [markdown]
# # Node
# https://opensees.ist.berkeley.edu/wiki/index.php?title=Getting_Started_with_OpenSees_--_Nodes
#
# ## Node
# https://opensees.ist.berkeley.edu/wiki/index.php?title=Node_command
# <p>node NO. x y</p>
#
# ## Fix
# https://opensees.ist.berkeley.edu/wiki/index.php?title=Fix_command
# <p>fix NO. dof1 dof2 dof3<br>
# 0 -> free<br>
# 1 -> fixed</p>
#
# ## Mass
# https://opensees.ist.berkeley.edu/wiki/index.php?title=Mass_Command
# <p>mass NO. dof1 dof2 dof3</p>
#
# ---
# <p>
#     node 1 0.0 0.0<br>
#     node 2 1.0 0.0<br>
#     node 3 0.0 1.0<br>
#     node 4 1.0 1.0<br>
#     <br>
#     fix 1 1 1 1<br>
#     fix 2 1 1 0<br>
#     fix 3 0 0 0<br>
#     fix 4 0 0 0<br>
#     <br>
#     mass 3 1 0 0<br>
#     mass 4 1 0 0<br>
# </p>

# %% [markdown]
# # Element
# https://opensees.ist.berkeley.edu/wiki/index.php?title=Getting_Started_with_OpenSees_--_Elements
#
# ## Geometric Transformation Command
#
# https://opensees.ist.berkeley.edu/wiki/index.php?title=Geometric_Transformation_Command
#
# <p>from the basic system to the global-coordinate system.</p>
#
# ### Linear Transformation
#
# ### PDelta Transformation
#
# ### Corotational Transformation
#
#
# ## Elastic Beam Column Element
# https://opensees.ist.berkeley.edu/wiki/index.php?title=Elastic_Beam_Column_Element
